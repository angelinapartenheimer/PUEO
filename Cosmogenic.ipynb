# %% [markdown]
# Requires CRPropa3 https://github.com/CRPropa/CRPropa3

# %%
from common import *
from cosmogenic import *

# %%
p_data, nu_data = read_crpropa('output_protons.txt')

# %%
CosmogenicSpectra_figure(p_data, nu_data)

# %%
#Smaller sim for quicker results; published version uses the full dataset
p_data, nu_data = read_crpropa('output_protons_small.txt')

# %%
Fp_figure(p_data, nu_data)

# %%
#Number of expected neutrinos for Auger best fit
Auger_cr, Auger_nu = read_crpropa('Auger_best_fit.txt')
Augerbins, AugerE2dNdE = best_fit_spectrum(Auger_cr, Auger_nu, 0.96, 4.8, 0, 10**10.55, 5e-9)
Nexp(Augerbins, AugerE2dNdE)
# Out:
# 0.0002761008163164237

# %%
#Number of expected neutrinos for TA best fit
TA_cr, TA_nu = read_crpropa('TA_best_fit.txt')
TAbins, TAE2dNdE = best_fit_spectrum(TA_cr, TA_nu, 2.06, 182, 3, 10**10.55, 5e-9)
Nexp(TAbins, TAE2dNdE)
# Out:
# 0.2869802334390898
